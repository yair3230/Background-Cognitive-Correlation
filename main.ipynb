# %%
import importlib

import consts
import data_analysis
import eda_background_math_verbal_py as eda
import data_tools
import graphs
import pandas as pd

# Reload if you edited files without restarting kernel
importlib.reload(eda)
importlib.reload(data_analysis)
importlib.reload(data_tools)
importlib.reload(graphs)
importlib.reload(consts)
# Out:
# <module 'consts' from 'D:\\Degree\\Semester 3\\Python\\final proj\\final-project\\consts.py'>

# %%
# --------- CONFIG ----------
CSV_PATH = "main_dataset.csv"
# ---------------------------

# %%
# load the data
df = data_tools.load_main_dataset(CSV_PATH)
eda_df = eda.create_eda_subset(df)
bias_df = pd.read_csv('analysis_results_full.csv')

# %%
result = data_analysis.compute_bias_correlation(bias_df)

# %%
graphs.plot_correlation_heatmap(result, title="Pearson Correlations")

# %%
graphs.bias_vs_stem(bias_df)

# %%
graphs.bias_vs_verbal(bias_df)

# %%
graphs.bias_vs_academic(bias_df)

# %% [markdown]
# ## Show spearman correlation between parents grades (HG = Highest Grade) to child's grade

# %%
corr = eda.preprocess_and_compute_correlations(eda_df)
print("Spearman correlation (numeric vars):")
print(corr.round(2))
# Out:
# Spearman correlation (numeric vars):
#                    mother_HG  father_HG  regular_classroom  math  verbal
# mother_HG               1.00       0.56               0.10  0.22    0.29
# father_HG               0.56       1.00               0.25  0.48    0.30
# regular_classroom       0.10       0.25               1.00  0.09    0.05
# math                    0.22       0.48               0.09  1.00    0.52
# verbal                  0.29       0.30               0.05  0.52    1.00

# %% [markdown]
# ## Correlation matrix (numeric vars)

# %%
graphs.plot_correlation_heatmap(corr, title="Spearman Correlations (Numeric Vars)")

# %%
# Verbal-only correlations
verbal_corr = eda.verbal_correlation(eda_df)
print("\nSpearman correlation (Parental education + VIQ):")
print(verbal_corr.round(2))
# Out:
# Spearman correlation (Parental education + VIQ):
#            mother_HG  father_HG  verbal
# mother_HG       1.00       0.56    0.29
# father_HG       0.56       1.00    0.30
# verbal          0.29       0.30    1.00

# %% [markdown]
# ## Scatter plots

# %%
graphs.father_education_verbal(eda_df)

# %%
graphs.father_education_math(eda_df)

# %%
graphs.mother_education_verbal(eda_df)

# %%
graphs.mother_education_math(eda_df)

# %%
graphs.race_correlation(df)

# %%
graphs.mother_income_correlation(df)

# %%
graphs.father_income_correlation(df)

# %%
graphs.stage_A(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       total_math_score   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     14.15
# Date:                Wed, 14 Jan 2026   Prob (F-statistic):           2.25e-05
# Time:                        18:31:49   Log-Likelihood:                -49.461
# No. Observations:                  43   AIC:                             104.9
# Df Residuals:                      40   BIC:                             110.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -1.8855      1.034     -1.823      0.076      -3.976       0.205
# total_verbal_score         0.7413      0.252      2.938      0.005       0.231       1.251
# AWMA-S_VerbalWM_StS_t2     0.0189      0.010      1.922      0.062      -0.001       0.039
# ==============================================================================
# Omnibus:                        0.621   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.733   Jarque-Bera (JB):                0.733
# Skew:                           0.178   Prob(JB):                        0.693
# Kurtosis:                       2.468   Cond. No.                         969.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Stage A N: 43

# %%
graphs.stage_B(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       total_math_score   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     12.95
# Date:                Wed, 14 Jan 2026   Prob (F-statistic):           5.93e-07
# Time:                        18:32:07   Log-Likelihood:                -46.054
# No. Observations:                  47   AIC:                             102.1
# Df Residuals:                      42   BIC:                             111.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.1109      0.637      0.174      0.863      -1.175       1.397
# total_verbal_score       0.9951      0.188      5.296      0.000       0.616       1.374
# mother_highest_grade    -0.0335      0.167     -0.201      0.842      -0.370       0.303
# father_highest_grade     0.2290      0.119      1.923      0.061      -0.011       0.469
# regular_classroom       -0.7872      0.366     -2.152      0.037      -1.525      -0.049
# ==============================================================================
# Omnibus:                        4.507   Durbin-Watson:                   1.136
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                3.369
# Skew:                          -0.603   Prob(JB):                        0.186
# Kurtosis:                       3.516   Cond. No.                         39.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
graphs.hierarchial_model(df)
# Out:
# ΔR² (Stage B – Stage A) = 0.138
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0      40.0  25.124649      0.0       NaN       NaN     NaN
# 1      42.0  19.530935     -2.0  5.593714 -6.014458     NaN

# %%
graphs.residuals_graph(df)

# %%
graphs.residuals_distribution_graph(df)

# %%
graphs.residuals_plot(df)

# %%
graphs.influence_plot(df)
